# %%
#importing required libraries
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
import imutils
from sklearn import svm

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from keras.models import load_model

# %%
#loading the images into the notebook
from google.colab import files
files.upload()

# %%
image_list = []
image_cat = []
categories = ["VanGohg" , "Not"]
for i in range(1,34):
  #looping through images and converting to jpg
    image=Image.open(str(i)+'.jpg')
    #resizing the image
    image=image.resize((400, 400))
    #appending to the list
    image_list.append(np.asarray(image))
    cat_num = categories.index(categories[0]) 
    image_cat.append(cat_num)

for i in range(34,67):
  #looping through images and converting to jpg
    image=Image.open(str(i)+'.jpg')
    #resizing the image
    image=image.resize((400, 400))
    #appending to the list
    image_list.append(np.asarray(image))
    cat_num = categories.index(categories[1]) 
    image_cat.append(cat_num)

#appending to array
images = np.array(image_list)
image_cat = np.array(image_cat)

# %%
plt.imshow(images[50])

# %%
#extracting features
kp_img=[]
for i in range(66):
  #grayscaling images
  grayimg = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
  #initiating ORB detector
  orb = cv2.ORB_create(nfeatures=1000)
  #finding keypoints and detectors for both images
  kpt, desc = orb.detectAndCompute(grayimg,None)

  #storing the descriptor in a dict
  #desc_list = {}
  #desc_list.setdefault(i,[]).append(desc)
  #print(desc_list)
  #kp_list = {}
  #kp_list.setdefault(i,[]).append(kpt)

  img = cv2.drawKeypoints(grayimg, kpt, None)
  kp_img.append(np.asarray(img))

  #print(kp_list)
features = np.array(kp_img)
#print(features)

# %%
plt.imshow(features[10])

# %%
#making training dataset
X = features
y = image_cat

# %%
#reshapnig X for SVM
#X_2d = X.reshape(66,-1)

# %%
#normalizing the dataset
X = utils.normalize(X, axis=1)

# %%
#assert not np.any(np.isnan(X))

# %%
#splitting the data into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %% [markdown]
# #SVM

# %%
#fitting data to binary classifier
clf = svm.SVC(random_state=0).fit(X_train, y_train)

# %%
#getting the accuracy on training dataset
clf.score(X_train, y_train)
# Out:
# 0.8983050847457628

# %%
#accuracy on test dataset
clf.score(X_test, y_test)
# Out:
# 0.5714285714285714

# %%
#making predictions
pred = clf.predict(X_2d)
preds_img = [X,pred,y]

# %%
for i in range(60):
  print("Image index:", i, "Predicted label:", preds_img[1][i], "Original label:", preds_img[2][i])
# Out:
# Image index: 0 Predicted label: 0 Original label: 0
# Image index: 1 Predicted label: 0 Original label: 0
# Image index: 2 Predicted label: 0 Original label: 0
# Image index: 3 Predicted label: 0 Original label: 0
# Image index: 4 Predicted label: 0 Original label: 0
# Image index: 5 Predicted label: 0 Original label: 0
# Image index: 6 Predicted label: 0 Original label: 0
# Image index: 7 Predicted label: 0 Original label: 0
# Image index: 8 Predicted label: 0 Original label: 0
# Image index: 9 Predicted label: 0 Original label: 0
# Image index: 10 Predicted label: 0 Original label: 0
# Image index: 11 Predicted label: 0 Original label: 0
# Image index: 12 Predicted label: 0 Original label: 0
# Image index: 13 Predicted label: 0 Original label: 0
# Image index: 14 Predicted label: 0 Original label: 0
# Image index: 15 Predicted label: 0 Original label: 0
# Image index: 16 Predicted label: 1 Original label: 0
# Image index: 17 Predicted label: 0 Original label: 0
# Image index: 18 Predicted label: 0 Original label: 0
# Image index: 19 Predicted label: 0 Original label: 0
# Image index: 20 Predicted label: 0 Original label: 0
# Image index: 21 Predicted label: 0 Original label: 0
# Image index: 22 Predicted label: 0 Original label: 0
# Image index: 23 Predicted label: 0 Original label: 0
# Image index: 24 Predicted label: 0 Original label: 0
# Image index: 25 Predicted label: 0 Original label: 0
# Image index: 26 Predicted label: 0 Original label: 0
# Image index: 27 Predicted label: 0 Original label: 0
# Image index: 28 Predicted label: 0 Original label: 0
# Image index: 29 Predicted label: 0 Original label: 0
# Image index: 30 Predicted label: 0 Original label: 0
# Image index: 31 Predicted label: 0 Original label: 0
# Image index: 32 Predicted label: 0 Original label: 0
# Image index: 33 Predicted label: 1 Original label: 1
# Image index: 34 Predicted label: 1 Original label: 1
# Image index: 35 Predicted label: 0 Original label: 1
# Image index: 36 Predicted label: 0 Original label: 1
# Image index: 37 Predicted label: 1 Original label: 1
# Image index: 38 Predicted label: 1 Original label: 1
# Image index: 39 Predicted label: 0 Original label: 1
# Image index: 40 Predicted label: 0 Original label: 1
# Image index: 41 Predicted label: 1 Original label: 1
# Image index: 42 Predicted label: 1 Original label: 1
# Image index: 43 Predicted label: 1 Original label: 1
# Image index: 44 Predicted label: 1 Original label: 1
# Image index: 45 Predicted label: 0 Original label: 1
# Image index: 46 Predicted label: 1 Original label: 1
# Image index: 47 Predicted label: 1 Original label: 1
# Image index: 48 Predicted label: 1 Original label: 1
# Image index: 49 Predicted label: 1 Original label: 1
# Image index: 50 Predicted label: 1 Original label: 1
# Image index: 51 Predicted label: 1 Original label: 1
# Image index: 52 Predicted label: 1 Original label: 1
# Image index: 53 Predicted label: 0 Original label: 1
# Image index: 54 Predicted label: 1 Original label: 1
# Image index: 55 Predicted label: 0 Original label: 1
# Image index: 56 Predicted label: 1 Original label: 1
# Image index: 57 Predicted label: 1 Original label: 1
# Image index: 58 Predicted label: 1 Original label: 1
# Image index: 59 Predicted label: 1 Original label: 1

# %%
plt.imshow(preds_img[0][45])

# %%
#saving the model
model.save("art.h5")

# %% [markdown]
# #Test Case

# %%
#preprocessing the test image
test_img = cv2.imread("test1.jpg")
test_img = test_img.resize((400, 400))

#finding keypoints and detectors for both images
kp_img=[]
grayimg = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
orb = cv2.ORB_create(nfeatures=1000)

kpt, desc = orb.detectAndCompute(grayimg,None)
img = cv2.drawKeypoints(grayimg, kpt, None)
kp_img.append(np.asarray(img))
features = np.array(kp_img)

# %%
#reshaping the features for svm
#features = features.reshape(1,-1)

# %%
#making predictions
pred = model.predict(features)

# %%
print(pred)
# Out:
# [[0.]]

# %% [markdown]
# #Building Model

# %%
#building a seq2seq model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3),activation='relu', input_shape=(400,400,3)))
model.add(Conv2D(filters=32,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(Conv2D(filters=128,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=256,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(Conv2D(filters=256,kernel_size=(3,3),padding='Same',activation='relu', kernel_initializer = 'he_uniform'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer = 'he_uniform'))
model.add(Dense(128, activation='relu', kernel_initializer = 'he_uniform'))
model.add(Dense(1, activation='sigmoid'))

#defining the batch sizes and epochs
batch_size = 30
epochs = 40
opt = SGD()

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=50)

# %%
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()

# %%
#training the model
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, 
                    verbose=1, validation_data=(X_test, y_test), callbacks = [early_stop])
# Out:
# Epoch 1/40
# 2/2 [==============================] - 12s 11s/step - loss: 0.6916 - accuracy: 0.5424 - val_loss: 0.6970 - val_accuracy: 0.4286
# Epoch 2/40
# 2/2 [==============================] - 1s 443ms/step - loss: 0.6856 - accuracy: 0.5085 - val_loss: 0.7003 - val_accuracy: 0.4286
# Epoch 3/40
# 2/2 [==============================] - 1s 433ms/step - loss: 0.6821 - accuracy: 0.5085 - val_loss: 0.6987 - val_accuracy: 0.4286
# Epoch 4/40
# 2/2 [==============================] - 1s 432ms/step - loss: 0.6815 - accuracy: 0.5254 - val_loss: 0.7040 - val_accuracy: 0.4286
# Epoch 5/40
# 2/2 [==============================] - 1s 440ms/step - loss: 0.6846 - accuracy: 0.5085 - val_loss: 0.6969 - val_accuracy: 0.4286
# Epoch 6/40
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6768 - accuracy: 0.5932 - val_loss: 0.7054 - val_accuracy: 0.4286
# Epoch 7/40
# 2/2 [==============================] - 1s 434ms/step - loss: 0.6743 - accuracy: 0.5085 - val_loss: 0.7070 - val_accuracy: 0.4286
# Epoch 8/40
# 2/2 [==============================] - 1s 466ms/step - loss: 0.6682 - accuracy: 0.5085 - val_loss: 0.7022 - val_accuracy: 0.4286
# Epoch 9/40
# 2/2 [==============================] - 1s 466ms/step - loss: 0.6630 - accuracy: 0.5424 - val_loss: 0.7070 - val_accuracy: 0.4286
# Epoch 10/40
# 2/2 [==============================] - 1s 438ms/step - loss: 0.6586 - accuracy: 0.5424 - val_loss: 0.7099 - val_accuracy: 0.4286
# Epoch 11/40
# 2/2 [==============================] - 1s 442ms/step - loss: 0.6576 - accuracy: 0.5763 - val_loss: 0.7192 - val_accuracy: 0.4286
# Epoch 12/40
# 2/2 [==============================] - 1s 435ms/step - loss: 0.6639 - accuracy: 0.5763 - val_loss: 0.7142 - val_accuracy: 0.4286
# Epoch 13/40
# 2/2 [==============================] - 1s 437ms/step - loss: 0.6706 - accuracy: 0.6102 - val_loss: 0.7203 - val_accuracy: 0.4286
# Epoch 14/40
# 2/2 [==============================] - 1s 445ms/step - loss: 0.6468 - accuracy: 0.5254 - val_loss: 0.7110 - val_accuracy: 0.4286
# Epoch 15/40
# 2/2 [==============================] - 1s 438ms/step - loss: 0.6400 - accuracy: 0.5932 - val_loss: 0.7172 - val_accuracy: 0.4286
# Epoch 16/40
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6482 - accuracy: 0.6780 - val_loss: 0.7282 - val_accuracy: 0.4286
# Epoch 17/40
# 2/2 [==============================] - 1s 440ms/step - loss: 0.6617 - accuracy: 0.6102 - val_loss: 0.7339 - val_accuracy: 0.4286
# Epoch 18/40
# 2/2 [==============================] - 1s 445ms/step - loss: 0.6369 - accuracy: 0.5254 - val_loss: 0.7013 - val_accuracy: 0.4286
# Epoch 19/40
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6501 - accuracy: 0.6780 - val_loss: 0.7035 - val_accuracy: 0.4286
# Epoch 20/40
# 2/2 [==============================] - 1s 445ms/step - loss: 0.6273 - accuracy: 0.7119 - val_loss: 0.7146 - val_accuracy: 0.4286
# Epoch 21/40
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6318 - accuracy: 0.6441 - val_loss: 0.7022 - val_accuracy: 0.4286
# Epoch 22/40
# 2/2 [==============================] - 1s 446ms/step - loss: 0.6350 - accuracy: 0.8136 - val_loss: 0.7087 - val_accuracy: 0.4286
# Epoch 23/40
# 2/2 [==============================] - 1s 438ms/step - loss: 0.6031 - accuracy: 0.7966 - val_loss: 0.7498 - val_accuracy: 0.4286
# Epoch 24/40
# 2/2 [==============================] - 1s 449ms/step - loss: 0.6177 - accuracy: 0.6780 - val_loss: 0.7398 - val_accuracy: 0.4286
# Epoch 25/40
# 2/2 [==============================] - 1s 436ms/step - loss: 0.5953 - accuracy: 0.6102 - val_loss: 0.7015 - val_accuracy: 0.4286
# Epoch 26/40
# 2/2 [==============================] - 1s 444ms/step - loss: 0.5970 - accuracy: 0.8983 - val_loss: 0.7537 - val_accuracy: 0.4286
# Epoch 27/40
# 2/2 [==============================] - 1s 447ms/step - loss: 0.5651 - accuracy: 0.7119 - val_loss: 0.7001 - val_accuracy: 0.4286
# Epoch 28/40
# 2/2 [==============================] - 1s 442ms/step - loss: 0.6065 - accuracy: 0.6441 - val_loss: 0.6956 - val_accuracy: 0.5714
# Epoch 29/40
# 2/2 [==============================] - 1s 443ms/step - loss: 0.6001 - accuracy: 0.7288 - val_loss: 0.7752 - val_accuracy: 0.4286
# Epoch 30/40
# 2/2 [==============================] - 1s 438ms/step - loss: 0.5655 - accuracy: 0.7627 - val_loss: 0.7387 - val_accuracy: 0.4286
# Epoch 31/40
# 2/2 [==============================] - 1s 453ms/step - loss: 0.5304 - accuracy: 0.7966 - val_loss: 0.7133 - val_accuracy: 0.2857
# Epoch 32/40
# 2/2 [==============================] - 1s 449ms/step - loss: 0.5808 - accuracy: 0.7797 - val_loss: 1.0664 - val_accuracy: 0.4286
# Epoch 33/40
# 2/2 [==============================] - 1s 439ms/step - loss: 0.7040 - accuracy: 0.6102 - val_loss: 0.7019 - val_accuracy: 0.2857
# Epoch 34/40
# 2/2 [==============================] - 1s 444ms/step - loss: 0.6394 - accuracy: 0.7288 - val_loss: 0.7356 - val_accuracy: 0.4286
# Epoch 35/40
# 2/2 [==============================] - 1s 445ms/step - loss: 0.6108 - accuracy: 0.6271 - val_loss: 0.7048 - val_accuracy: 0.4286
# Epoch 36/40
# 2/2 [==============================] - 1s 439ms/step - loss: 0.5845 - accuracy: 0.7797 - val_loss: 0.7061 - val_accuracy: 0.5714
# Epoch 37/40
# 2/2 [==============================] - 1s 466ms/step - loss: 0.5516 - accuracy: 0.8305 - val_loss: 0.7037 - val_accuracy: 0.5714
# Epoch 38/40
# 2/2 [==============================] - 1s 448ms/step - loss: 0.5576 - accuracy: 0.7288 - val_loss: 0.7022 - val_accuracy: 0.5714
# Epoch 39/40
# 2/2 [==============================] - 1s 448ms/step - loss: 0.5916 - accuracy: 0.6780 - val_loss: 0.7145 - val_accuracy: 0.4286
# Epoch 40/40
# 2/2 [==============================] - 1s 443ms/step - loss: 0.4966 - accuracy: 0.8644 - val_loss: 0.7001 - val_accuracy: 0.4286

# %%
#evaluating model over test dataset
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 68ms/step - loss: 0.7001 - accuracy: 0.4286
# [0.700130045413971, 0.4285714328289032]

# %%
model.save("paintings.h5")

# %%
#loading the model in the notebook
#model = load_model('paintings.h5')

# %% [markdown]
# #Prediction

# %%
pred = model.predict_classes(X_test)
preds_img = [X_test,pred,y_test]
for i in range(7):
  print("Image index:", i, "Predicted label:", preds_img[1][i], "Original label:", preds_img[2][i])
# Out:
# Image index: 0 Predicted label: [1] Original label: 1
# Image index: 1 Predicted label: [1] Original label: 1
# Image index: 2 Predicted label: [1] Original label: 0
# Image index: 3 Predicted label: [1] Original label: 1
# Image index: 4 Predicted label: [1] Original label: 0
# Image index: 5 Predicted label: [0] Original label: 1
# Image index: 6 Predicted label: [1] Original label: 0
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
plt.imshow(preds_img[0][1])
